# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../data/merged/merged_airbnb_host.csv')

# %%
sns.pairplot(df)

# %%
df['price_per_night'] = df['price_per_night'].str.strip("$")

# %%
df['price_per_night'] = df['price_per_night'].replace(',',"")

# %%
df['price_per_night'].repla
# Out:
# price_per_night
# 40        39
# 20        35
# 30        33
# 32        25
# 50        24
#           ..
# 1,314      1
# 215        1
# 152        1
# 102        1
# 138        1
# Name: count, Length: 120, dtype: int64
